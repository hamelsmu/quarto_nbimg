# %% [markdown]
# #
#
# <figure>
# <img
# src="attachment:example_files/figure-ipynb/94905425-1-63d3c95d-f602-4708-a909-a1ec8a154012.png"
# class="border rounded shadow-sm" data-fig-align="center"
# alt="image.png" />
# <figcaption aria-hidden="true">image.png</figcaption>
# </figure>
